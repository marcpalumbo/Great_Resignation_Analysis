# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
file_path = Path('Cleaned Data/industry.csv')
df = pd.read_csv(file_path)
df.head()
# Out:
#    id                                        description
# 0   1                         Wage and salary employment
# 1   2  Proprietors employment Farm proprietors employ...
# 2   3  Proprietors employmentNonfarm proprietors empl...
# 3   4                                    Farm employment
# 4   5  Nonfarm employment Private nonfarm employment ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     id                                        description
# 0    1                         Wage and salary employment
# 1    2  Proprietors employment Farm proprietors employ...
# 2    3  Proprietors employmentNonfarm proprietors empl...
# 3    4                                    Farm employment
# 4    5  Nonfarm employment Private nonfarm employment ...
# 5    6  Nonfarm employment Private nonfarm employment ...
# 6    7  Nonfarm employment Private nonfarm employment ...
# 7    8  Nonfarm employment Private nonfarm employment ...
# 8    9  Nonfarm employment Private nonfarm employment ...
# 9   10  Nonfarm employment Private nonfarm employment ...
# 10  11  Nonfarm employment Private nonfarm employment ...
# 11  12  Nonfarm employment Private nonfarm employment ...
# 12  13  Nonfarm employment Private nonfarm employment ...
# 13  14  Nonfarm employment Private nonfarm employment ...
# 14  15  Nonfarm employment Private nonfarm employment ...
# ...

# %%
df.reset_index()
df
# Out:
#     id                                        description
# 0    1                         Wage and salary employment
# 1    2  Proprietors employment Farm proprietors employ...
# 2    3  Proprietors employmentNonfarm proprietors empl...
# 3    4                                    Farm employment
# 4    5  Nonfarm employment Private nonfarm employment ...
# 5    6  Nonfarm employment Private nonfarm employment ...
# 6    7  Nonfarm employment Private nonfarm employment ...
# 7    8  Nonfarm employment Private nonfarm employment ...
# 8    9  Nonfarm employment Private nonfarm employment ...
# 9   10  Nonfarm employment Private nonfarm employment ...
# 10  11  Nonfarm employment Private nonfarm employment ...
# 11  12  Nonfarm employment Private nonfarm employment ...
# 12  13  Nonfarm employment Private nonfarm employment ...
# 13  14  Nonfarm employment Private nonfarm employment ...
# 14  15  Nonfarm employment Private nonfarm employment ...
# ...

# %%
file_path1 = Path('Cleaned Data/cleaned_geographic_data.csv')
df1 = pd.read_csv(file_path1)
df1.head()
# Out:
#    id                         GeoName  \
# 0   1  Alabama (Metropolitan Portion)
# 1   2  Alabama (Metropolitan Portion)
# 2   3  Alabama (Metropolitan Portion)
# 3   4  Alabama (Metropolitan Portion)
# 4   6  Alabama (Metropolitan Portion)
#
#                                          Description     2016     2017  \
# 0                         Wage and salary employment  1643706  1664641
# 1  Proprietors employment Farm proprietors employ...    17653    17142
# 2  Proprietors employmentNonfarm proprietors empl...   423880   432197
# 3                                    Farm employment    21352    21534
# 4  Nonfarm employment Private nonfarm employment ...     8693     7939
#
#       2018     2019     2020
# 0  1686588  1711156  1643053
# 1    16771    16389    16466
# 2   447698   442971   428638
# 3    20490    19416    19872
# 4     7353     7000     6494

# %%
df1.tail()
# Out:
#       id                               GeoName  \
# 2570  13  Far West (Nonmetropolitan Portion) *
# 2571  23  Far West (Nonmetropolitan Portion) *
# 2572  24  Far West (Nonmetropolitan Portion) *
# 2573  25  Far West (Nonmetropolitan Portion) *
# 2574  27  Far West (Nonmetropolitan Portion) *
#
#                                             Description    2016    2017  \
# 2570  Nonfarm employment Private nonfarm employment ...   13469   12712
# 2571  Nonfarm employment Private nonfarm employment ...   87123   86248
# 2572  Government and government enterprises Federal ...   26206   25946
# 2573     Government and government enterprises Military   22225   23324
# 2574  Government and government enterprises State an...  180134  181891
#
#         2018    2019    2020
# 2570   12631   11943   12356
# 2571   89268   85980   81755
# 2572   25362   25451   26608
# 2573   21271   21907   21728
# 2574  184070  184103  170533

# %%
#renaming column to lowercase 'description'


df1.columns = ['description' if x == 'Description' else x for x in df1.columns]
df1.head()
# Out:
#    id                         GeoName  \
# 0   1  Alabama (Metropolitan Portion)
# 1   2  Alabama (Metropolitan Portion)
# 2   3  Alabama (Metropolitan Portion)
# 3   4  Alabama (Metropolitan Portion)
# 4   6  Alabama (Metropolitan Portion)
#
#                                          description     2016     2017  \
# 0                         Wage and salary employment  1643706  1664641
# 1  Proprietors employment Farm proprietors employ...    17653    17142
# 2  Proprietors employmentNonfarm proprietors empl...   423880   432197
# 3                                    Farm employment    21352    21534
# 4  Nonfarm employment Private nonfarm employment ...     8693     7939
#
#       2018     2019     2020
# 0  1686588  1711156  1643053
# 1    16771    16389    16466
# 2   447698   442971   428638
# 3    20490    19416    19872
# 4     7353     7000     6494

# %%
#begin connecting to SQl 
##import 
from sqlalchemy import create_engine
#import password 
from config import db_password

# %%
#create database strinng
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Great_Resignation_Analysis"

# %%
#creating engine
engine = create_engine(db_string)

# %%
#saving df4 table to 
df1.to_sql(name='geographic_data',con =engine,index= False,if_exists='replace' )

# %%
#exporting industry data to postgres

df.to_sql(name='industry',con =engine,index= False,if_exists='replace' )
