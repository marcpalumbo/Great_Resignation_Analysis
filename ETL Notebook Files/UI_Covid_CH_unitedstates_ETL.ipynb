# %% [markdown]
# # Load 'covidcredithealth_us.csv' from Urban Institute and preview 'df_dict'

# %%
# Import dependencies.
import pandas as pd
from pathlib import Path
import numpy as np

# %%
# Load the data.
file_path = Path('../Resources/covidcredithealth_us.csv')
df_Covid_CH_unitedstates = pd.read_csv(file_path)

# %%
# Preview the data.
df_Covid_CH_unitedstates.head(8)
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
# 5     2020_12                                  22.17
# 6     2021_02                                  21.71
# 7     2021_08                                  20.29
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
# 5                                              31.24
# 6                                              30.68
# ...

# %%
# Display datatypes for each column.
df_Covid_CH_unitedstates.dtypes
# Out:
# Time Period                                                                          object
# Share with Subprime Credit Score, All                                               float64
# Share with Subprime Credit Score, Communities of Color                              float64
# Share with Subprime Credit Score, Majority White Communities                        float64
# Share with Subprime Credit Score, Majority Black Communities                        float64
#                                                                                      ...
# Share with Medical Debt in Collections, Communities of Color                        float64
# Share with Medical Debt in Collections, Majority White Communities                  float64
# Share with Medical Debt in Collections, Majority Black Communities                  float64
# Share with Medical Debt in Collections, Majority Hispanic/Latinx Communities        float64
# ...

# %%
# Check for Missing Values
df_Covid_CH_unitedstates.isnull().any()
# Out:
# Time Period                                                                         False
# Share with Subprime Credit Score, All                                               False
# Share with Subprime Credit Score, Communities of Color                              False
# Share with Subprime Credit Score, Majority White Communities                        False
# Share with Subprime Credit Score, Majority Black Communities                        False
#                                                                                     ...
# Share with Medical Debt in Collections, Communities of Color                        False
# Share with Medical Debt in Collections, Majority White Communities                  False
# Share with Medical Debt in Collections, Majority Black Communities                  False
# Share with Medical Debt in Collections, Majority Hispanic/Latinx Communities        False
# ...

# %%
# Dimensions of our dataset.
df_Covid_CH_unitedstates.shape
# Out:
# (8, 79)

# %%
# Summary for each variable
df_Covid_CH_unitedstates.describe()
# Out:
#        Share with Subprime Credit Score, All  \
# count                               8.000000
# mean                               22.641250
# std                                 1.387706
# min                                20.290000
# 25%                                22.055000
# 50%                                22.535000
# 75%                                23.317500
# max                                24.880000
#
#        Share with Subprime Credit Score, Communities of Color  \
# count                                           8.000000
# mean                                           31.891250
# std                                             1.834654
# min                                            28.720000
# 25%                                            31.100000
# 50%                                            31.780000
# 75%                                            32.860000
# max                                            34.770000
#
# ...

# %% [markdown]
# # ETL Method

# %%
# Print total rows of new DataFrame. 
print(f" There are {len(df_Covid_CH_unitedstates)} total rows in the dataframe.")

# Show NaN values.
df_Covid_CH_unitedstates.isna().sum()
# Out:
#  There are 8 total rows in the dataframe.
# Time Period                                                                         0
# Share with Subprime Credit Score, All                                               0
# Share with Subprime Credit Score, Communities of Color                              0
# Share with Subprime Credit Score, Majority White Communities                        0
# Share with Subprime Credit Score, Majority Black Communities                        0
#                                                                                    ..
# Share with Medical Debt in Collections, Communities of Color                        0
# Share with Medical Debt in Collections, Majority White Communities                  0
# Share with Medical Debt in Collections, Majority Black Communities                  0
# Share with Medical Debt in Collections, Majority Hispanic/Latinx Communities        0
# ...

# %%
# Explore data.
df_Covid_CH_unitedstates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 79 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   Time Period                                                                       8 non-null      object
#  1   Share with Subprime Credit Score, All                                             8 non-null      float64
#  2   Share with Subprime Credit Score, Communities of Color                            8 non-null      float64
#  3   Share with Subprime Credit Score, Majority White Communities                      8 non-null      float64
#  4   Share with Subprime Credit Score, Majority Black Communities                      8 non-null      float64
# ...

# %% [markdown]
# Convert columns with 'object' data types as an integers or 'int'.

# %%
# Verify selected column for preview analysis is an object.
df_Covid_CH_unitedstates['Median Debt in Collections, All'].dtype
# Out:
# dtype('O')

# %%
# Use DataFrame.columns() to previw columns with 'object'.

# 'Time Period' column.
for column in df_Covid_CH_unitedstates.columns[:1]:
     print(df_Covid_CH_unitedstates[column].head())

# 'median debt in collections...' column.
for column in df_Covid_CH_unitedstates.columns[13:19]:
    print(df_Covid_CH_unitedstates[column].head())

# 'median medical debt in collection...' column.
for column in df_Covid_CH_unitedstates.columns[67:73]:
    print(df_Covid_CH_unitedstates[column].head())
# Out:
# 0    2020_02
# 1    2020_04
# 2    2020_06
# 3    2020_08
# 4    2020_10
# Name: Time Period, dtype: object
# 0    $1833
# 1    $1829
# 2    $1848
# 3    $1860
# 4    $1849
# Name: Median Debt in Collections, All, dtype: object
# 0    $1869
# 1    $1868
# 2    $1893
# 3    $1913
# 4    $1900
# Name: Median Debt in Collections, Communities of Color, dtype: object
# 0    $1785
# 1    $1776
# 2    $1793
# 3    $1800
# 4    $1792
# Name: Median Debt in Collections, Majority White Communities, dtype: object
# 0    $1910
# 1    $1911
# 2    $1917
# 3    $1923
# 4    $1908
# Name: Median Debt in Collections, Majority Black Communities, dtype: object
# 0    $1,833
# 1      $1831
# 2      $1863
# 3      $1891
# 4      $1882
# Name: Median Debt in Collections, Majority Hispanic/Latinx Communities, dtype: object
# 0    $2310
# 1    $2297
# 2    $2169
# 3    $2147
# 4    $2088
# Name: Median Debt in Collections, Majority American Indian and Alaskan Native Communit, dtype: object
# 0    $782
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Debt in Collections, All'] = df_Covid_CH_unitedstates['Median Debt in Collections, All'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Debt in Collections, Communities of Color'] = df_Covid_CH_unitedstates['Median Debt in Collections, Communities of Color'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Debt in Collections, Majority White Communities'] = df_Covid_CH_unitedstates['Median Debt in Collections, Majority White Communities'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Debt in Collections, Majority Black Communities'] = df_Covid_CH_unitedstates['Median Debt in Collections, Majority Black Communities'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Debt in Collections, Majority Hispanic/Latinx Communities'] = df_Covid_CH_unitedstates['Median Debt in Collections, Majority Hispanic/Latinx Communities'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Debt in Collections, Majority American Indian and Alaskan Native Communit'] = df_Covid_CH_unitedstates['Median Debt in Collections, Majority American Indian and Alaskan Native Communit'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Medical Debt in Collections, All'] = df_Covid_CH_unitedstates['Median Medical Debt in Collections, All'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Medical Debt in Collections, Communities of Color'] = df_Covid_CH_unitedstates['Median Medical Debt in Collections, Communities of Color'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Medical Debt in Collections, Majority White Communities'] = df_Covid_CH_unitedstates['Median Medical Debt in Collections, Majority White Communities'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Medical Debt in Collections, Majority Black Communities'] = df_Covid_CH_unitedstates['Median Medical Debt in Collections, Majority Black Communities'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Medical Debt in Collections, Majority Hispanic/Latinx Communities'] = df_Covid_CH_unitedstates['Median Medical Debt in Collections, Majority Hispanic/Latinx Communities'].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_unitedstates['Median Medical Debt in Collections, Majority American Indian and Alaskan Native '] = df_Covid_CH_unitedstates['Median Medical Debt in Collections, Majority American Indian and Alaskan Native '].apply(lambda x: x.replace('$', '').replace(',', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_unitedstates.head()
# Out:
#   Time Period  Share with Subprime Credit Score, All  \
# 0     2020_02                                  24.88
# 1     2020_04                                  23.88
# 2     2020_06                                  23.13
# 3     2020_08                                  22.70
# 4     2020_10                                  22.37
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              34.77
# 1                                              33.52
# 2                                              32.64
# 3                                              31.99
# 4                                              31.57
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              20.45
# 1                                              19.54
# 2                                              18.85
# 3                                              18.52
# ...

# %%
# Dimensions of new dataset.
df_Covid_CH_unitedstates.shape
# Out:
# (8, 79)

# %%
# Summary for each variable. 
df_Covid_CH_unitedstates.describe()
# Out:
#        Share with Subprime Credit Score, All  \
# count                               8.000000
# mean                               22.641250
# std                                 1.387706
# min                                20.290000
# 25%                                22.055000
# 50%                                22.535000
# 75%                                23.317500
# max                                24.880000
#
#        Share with Subprime Credit Score, Communities of Color  \
# count                                           8.000000
# mean                                           31.891250
# std                                             1.834654
# min                                            28.720000
# 25%                                            31.100000
# 50%                                            31.780000
# 75%                                            32.860000
# max                                            34.770000
#
# ...

# %%
# Verify that all dtypes in new Dataframe are int/float with the exception of 'Time Period' column for potential mapping purposes.
df_Covid_CH_unitedstates.dtypes
# Out:
# Time Period                                                                          object
# Share with Subprime Credit Score, All                                               float64
# Share with Subprime Credit Score, Communities of Color                              float64
# Share with Subprime Credit Score, Majority White Communities                        float64
# Share with Subprime Credit Score, Majority Black Communities                        float64
#                                                                                      ...
# Share with Medical Debt in Collections, Communities of Color                        float64
# Share with Medical Debt in Collections, Majority White Communities                  float64
# Share with Medical Debt in Collections, Majority Black Communities                  float64
# Share with Medical Debt in Collections, Majority Hispanic/Latinx Communities        float64
# ...

# %%
#Exporting cleaned data into new csv file.
df_Covid_CH_unitedstates.to_csv('Cleaned_UI_Covid_CH_unitedstates.csv')
