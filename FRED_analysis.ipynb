# %%
# Import dependencies.
import pandas as pd
from pathlib import Path
import numpy as np

import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the data.
file_path = Path('Working Resources/emp_level.csv')
df = pd.read_csv(file_path)

df
# Out:
#     observation_date  CE16OV
# 0         1948-01-01   58061
# 1         1948-02-01   58196
# 2         1948-03-01   57671
# 3         1948-04-01   58291
# 4         1948-05-01   57854
# ..               ...     ...
# 892       2022-05-01  158426
# 893       2022-06-01  158111
# 894       2022-07-01  158290
# 895       2022-08-01  158732
# 896       2022-09-01  158936
#
# [897 rows x 2 columns]

# %%
from matplotlib import style

# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

ax = df.plot(figsize=(16, 6))
ax.set_title("Total Number of Employees in All Industries")
ax.set_xlabel("Year")
ax.set_ylabel("Number of People Employed")
# Out:
# Text(0, 0.5, 'Number of People Employed')
