# %%
# Import dependencies.
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
from datetime import datetime

import seaborn as sns
import matplotlib.ticker as ticker

# %% [markdown]
# # Three Industries Most Affected

# %% [markdown]
# #### Manufacturing

# %%
# Load the data.
file_path = Path('../Cleaned Data/all_emp_manufacturing.csv')
df_emp_man = pd.read_csv(file_path)

# Display DataFrame.
df_emp_man.head(10)
# Out:
#   observation_date  MANEMP
# 0       1939-01-01    9077
# 1       1939-02-01    9175
# 2       1939-03-01    9275
# 3       1939-04-01    9309
# 4       1939-05-01    9299
# 5       1939-06-01    9315
# 6       1939-07-01    9231
# 7       1939-08-01    9400
# 8       1939-09-01    9604
# 9       1939-10-01    9873

# %% [markdown]
# #### Education and Health Services

# %%
# Load the data.
file_path = Path('../Cleaned Data/all_emp_edu.csv')
df_emp_edu = pd.read_csv(file_path)

# Display DataFrame.
df_emp_edu.head(10)
# Out:
#   observation_date  USEHS
# 0       1939-01-01   1381
# 1       1939-02-01   1384
# 2       1939-03-01   1387
# 3       1939-04-01   1389
# 4       1939-05-01   1399
# 5       1939-06-01   1406
# 6       1939-07-01   1411
# 7       1939-08-01   1412
# 8       1939-09-01   1424
# 9       1939-10-01   1415

# %% [markdown]
# #### Hospitality

# %%
# Load the data.
file_path = Path('../Cleaned Data/all_emp_hospitality.csv')
df_emp_hos = pd.read_csv(file_path)

# Display DataFrame.
df_emp_hos.head(10)
# Out:
#   observation_date  USLAH
# 0       1939-01-01   1860
# 1       1939-02-01   1867
# 2       1939-03-01   1877
# 3       1939-04-01   1887
# 4       1939-05-01   1888
# 5       1939-06-01   1895
# 6       1939-07-01   1897
# 7       1939-08-01   1899
# 8       1939-09-01   1918
# 9       1939-10-01   1910

# %% [markdown]
# #### Merge Datasets (3 Industries Most Affected)

# %%
# Merge Datasets.
three_industries_alpha = pd.merge(pd.merge(df_emp_man,df_emp_edu,on='observation_date'),df_emp_hos,on='observation_date')

# Display merged DataFrame.
three_industries_alpha.head(10)
# Out:
#   observation_date  MANEMP  USEHS  USLAH
# 0       1939-01-01    9077   1381   1860
# 1       1939-02-01    9175   1384   1867
# 2       1939-03-01    9275   1387   1877
# 3       1939-04-01    9309   1389   1887
# 4       1939-05-01    9299   1399   1888
# 5       1939-06-01    9315   1406   1895
# 6       1939-07-01    9231   1411   1897
# 7       1939-08-01    9400   1412   1899
# 8       1939-09-01    9604   1424   1918
# 9       1939-10-01    9873   1415   1910

# %%
# Rename columns.
three_industries_alpha = three_industries_alpha.rename(columns={"MANEMP": "Manufacturing", "USEHS": "Education and Health Services", "USLAH": "Hospitality"})

# Display DataFrame.
three_industries_alpha.head(10)
# Out:
#   observation_date  Manufacturing  Education and Health Services  Hospitality
# 0       1939-01-01           9077                           1381         1860
# 1       1939-02-01           9175                           1384         1867
# 2       1939-03-01           9275                           1387         1877
# 3       1939-04-01           9309                           1389         1887
# 4       1939-05-01           9299                           1399         1888
# 5       1939-06-01           9315                           1406         1895
# 6       1939-07-01           9231                           1411         1897
# 7       1939-08-01           9400                           1412         1899
# 8       1939-09-01           9604                           1424         1918
# 9       1939-10-01           9873                           1415         1910

# %%
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

ax = three_industries_alpha.plot(figsize=(24, 14), x="observation_date", y=["Manufacturing", "Education and Health Services", "Hospitality"])
ax.set_title("FRED Economic Data: Current Employment Statistics (Establishment Survey)")
ax.set_xlabel("Year")
ax.set_ylabel("Thousands of Persons (Seasonally Adjusted)")

# Setting the number of ticks.
plt.locator_params(axis='both', nbins=12)

# Save figure. 
plt.savefig("../Images/matplotlib/FRED_Economic_Data_alpha", dpi='figure', format=None, metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None)

# %% [markdown]
# # Three Industries Least Affected

# %% [markdown]
# #### Finance

# %%
# Load the data.
file_path = Path('../Cleaned Data/all_emp_fin.csv')
df_emp_fin = pd.read_csv(file_path)

# Display DataFrame.
df_emp_fin.head(10)
# Out:
#   observation_date  USFIRE
# 0       1939-01-01    1371
# 1       1939-02-01    1372
# 2       1939-03-01    1376
# 3       1939-04-01    1370
# 4       1939-05-01    1379
# 5       1939-06-01    1381
# 6       1939-07-01    1386
# 7       1939-08-01    1392
# 8       1939-09-01    1406
# 9       1939-10-01    1398

# %% [markdown]
# #### IT

# %%
# Load the data.
file_path = Path('../Cleaned Data/all_emp_info.csv')
df_emp_info = pd.read_csv(file_path)

# Display DataFrame.
df_emp_info.head(10)
# Out:
#   observation_date  USINFO
# 0       1939-01-01    1112
# 1       1939-02-01    1118
# 2       1939-03-01    1126
# 3       1939-04-01    1127
# 4       1939-05-01    1125
# 5       1939-06-01    1131
# 6       1939-07-01    1131
# 7       1939-08-01    1134
# 8       1939-09-01    1152
# 9       1939-10-01    1179

# %% [markdown]
# #### Professional & Business

# %%
# Load the data.
file_path = Path('../Cleaned Data/all_emp_prof_bus.csv')
df_emp_prof_bus = pd.read_csv(file_path)

# Display DataFrame.
df_emp_prof_bus.head(10)
# Out:
#   observation_date  USPBS
# 0       1939-01-01   1943
# 1       1939-02-01   1950
# 2       1939-03-01   1958
# 3       1939-04-01   1957
# 4       1939-05-01   1968
# 5       1939-06-01   1980
# 6       1939-07-01   1985
# 7       1939-08-01   1990
# 8       1939-09-01   2010
# 9       1939-10-01   2021

# %% [markdown]
# #### Merge Datasets (3 Industries Least Affected)

# %%
# Merge Datasets.
three_industries_beta = pd.merge(pd.merge(df_emp_fin,df_emp_info,on='observation_date'),df_emp_prof_bus,on='observation_date')
three_industries_beta.head(10)
# Out:
#   observation_date  USFIRE  USINFO  USPBS
# 0       1939-01-01    1371    1112   1943
# 1       1939-02-01    1372    1118   1950
# 2       1939-03-01    1376    1126   1958
# 3       1939-04-01    1370    1127   1957
# 4       1939-05-01    1379    1125   1968
# 5       1939-06-01    1381    1131   1980
# 6       1939-07-01    1386    1131   1985
# 7       1939-08-01    1392    1134   1990
# 8       1939-09-01    1406    1152   2010
# 9       1939-10-01    1398    1179   2021

# %%
# Rename columns.
three_industries_beta = three_industries_beta.rename(columns={"USFIRE": "Finance", "USINFO": "IT", "USPBS": "Professional & Business"})

# Display DataFrame. 
three_industries_beta.head(10)
# Out:
#   observation_date  Finance    IT  Professional & Business
# 0       1939-01-01     1371  1112                     1943
# 1       1939-02-01     1372  1118                     1950
# 2       1939-03-01     1376  1126                     1958
# 3       1939-04-01     1370  1127                     1957
# 4       1939-05-01     1379  1125                     1968
# 5       1939-06-01     1381  1131                     1980
# 6       1939-07-01     1386  1131                     1985
# 7       1939-08-01     1392  1134                     1990
# 8       1939-09-01     1406  1152                     2010
# 9       1939-10-01     1398  1179                     2021

# %%
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

ax = three_industries_beta.plot(figsize=(24, 14), x="observation_date", y=["Finance", "IT", "Professional & Business"])
ax.set_title("FRED Economic Data: Current Employment Statistics (Establishment Survey)")
ax.set_xlabel("Year")
ax.set_ylabel("Thousands of Persons (Seasonally Adjusted)")

# Setting the number of ticks.
plt.locator_params(axis='both', nbins=12)

# Save figure. 
plt.savefig("../Images/matplotlib/FRED_Economic_Data_beta", dpi='figure', format=None, metadata=None,
        bbox_inches=None, pad_inches=0.1,
        facecolor='auto', edgecolor='auto',
        backend=None)
