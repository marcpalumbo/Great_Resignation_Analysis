# %% [markdown]
# # Load 'covidcredithealth_state.xlsx' from Urban Institute and preview 'df_dict'

# %%
# Import dependencies.
import pandas as pd
from pathlib import Path
import numpy as np

# %%
# Define filepath. 
filepath = 'Resources/covidcredithealth_state.xlsx'

# Load excel file using Pandas.
df_dict = pd.read_excel(filepath, sheet_name=None)

# Preview
df_dict
# Out:
# {'State 2020_02':    state  Share with Subprime Credit Score, All  \
#  0     AK                                  25.02
#  1     AL                                  33.45
#  2     AR                                  32.93
#  3     AZ                                  26.45
#  4     CA                                  20.73
#  5     CO                                  20.41
#  6     CT                                  21.39
#  7     DC                                  26.10
#  8     DE                                  26.05
#  9     FL                                  26.81
#  10    GA                                  32.71
#  11    HI                                  16.60
#  12    IA                                  19.85
#  13    ID                                  19.76
#  14    IL                                  23.65
#  15    IN                                  27.06
#  16    KS                                  23.49
#  17    KY                                  29.87
# ...

# %% [markdown]
# # Preview each worksheet from 'df_dict'

# %%
# Get data from 'State 2020_02' worksheet.
df_state_feb_2020 = df_dict.get('State 2020_02')

#Preview
df_state_feb_2020.head(10)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  25.02
# 1    AL                                  33.45
# 2    AR                                  32.93
# 3    AZ                                  26.45
# 4    CA                                  20.73
# 5    CO                                  20.41
# 6    CT                                  21.39
# 7    DC                                  26.10
# 8    DE                                  26.05
# 9    FL                                  26.81
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.15
# 1                                              51.47
# 2                                              52.27
# 3                                              41.21
# 4                                              24.98
# 5                                              34.63
# 6                                              40.67
# ...

# %%
# Get data from 'State 2020_04' worksheet.
df_state_apr_2020 = df_dict.get('State 2020_04')

#Preview
df_state_apr_2020.head(10)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  24.23
# 1    AL                                  32.36
# 2    AR                                  31.80
# 3    AZ                                  25.32
# 4    CA                                  19.99
# 5    CO                                  19.57
# 6    CT                                  20.59
# 7    DC                                  25.16
# 8    DE                                  25.20
# 9    FL                                  25.59
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.06
# 1                                              50.18
# 2                                              50.80
# 3                                              39.79
# 4                                              24.08
# 5                                              33.47
# 6                                              39.69
# ...

# %%
# Get data from 'State 2020_06' worksheet.
df_state_may_2020 = df_dict.get('State 2020_06')

#Preview
df_state_may_2020.head(10)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  23.37
# 1    AL                                  31.77
# 2    AR                                  31.26
# 3    AZ                                  24.22
# 4    CA                                  19.29
# 5    CO                                  18.83
# 6    CT                                  19.78
# 7    DC                                  24.24
# 8    DE                                  24.47
# 9    FL                                  25.11
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              33.20
# 1                                              49.91
# 2                                              50.47
# 3                                              38.03
# 4                                              23.33
# 5                                              32.63
# 6                                              38.37
# ...

# %%
# Get data from 'County 2020_08' worksheet.
df_state_aug_2020 = df_dict.get('State 2020_08')

#Preview
df_state_aug_2020.head(10)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  23.09
# 1    AL                                  31.14
# 2    AR                                  30.85
# 3    AZ                                  23.68
# 4    CA                                  18.77
# 5    CO                                  18.47
# 6    CT                                  19.27
# 7    DC                                  23.48
# 8    DE                                  23.92
# 9    FL                                  24.86
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              33.86
# 1                                              48.74
# 2                                              48.63
# 3                                              37.32
# 4                                              22.72
# 5                                              32.45
# 6                                              37.73
# ...

# %%
# Get data from 'County 2020_10' worksheet.
df_state_oct_2020 = df_dict.get('State 2020_10')

#Preview
df_state_oct_2020.head(10)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  23.18
# 1    AL                                  30.78
# 2    AR                                  30.50
# 3    AZ                                  23.12
# 4    CA                                  18.28
# 5    CO                                  18.05
# 6    CT                                  18.75
# 7    DC                                  22.83
# 8    DE                                  23.37
# 9    FL                                  24.60
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              32.89
# 1                                              48.26
# 2                                              48.66
# 3                                              36.16
# 4                                              22.15
# 5                                              31.99
# 6                                              36.81
# ...

# %%
# Get data from 'County 2020_12' worksheet.
df_state_dec_2020 = df_dict.get('State 2020_12')

#Preview
df_state_dec_2020.head(10)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  22.62
# 1    AL                                  30.40
# 2    AR                                  30.19
# 3    AZ                                  22.87
# 4    CA                                  17.96
# 5    CO                                  17.80
# 6    CT                                  18.60
# 7    DC                                  22.37
# 8    DE                                  23.15
# 9    FL                                  24.32
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              32.85
# 1                                              47.65
# 2                                              48.13
# 3                                              35.94
# 4                                              21.80
# 5                                              31.36
# 6                                              36.59
# ...

# %%
# Get data from 'State 2021_02' worksheet.
df_state_feb_2021 = df_dict.get('State 2021_02')

#Preview
df_state_feb_2021.head(10)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  22.18
# 1    AL                                  30.07
# 2    AR                                  29.61
# 3    AZ                                  22.34
# 4    CA                                  17.58
# 5    CO                                  17.33
# 6    CT                                  17.90
# 7    DC                                  21.61
# 8    DE                                  22.61
# 9    FL                                  23.86
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              31.21
# 1                                              47.54
# 2                                              47.53
# 3                                              35.21
# 4                                              21.39
# 5                                              30.52
# 6                                              35.40
# ...

# %%
# Get data from 'County 2021_08' worksheet.
df_state_aug_2021 = df_dict.get('State 2021_08')

#Preview
df_state_aug_2021.head(10)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  21.04
# 1    AL                                  28.55
# 2    AR                                  27.76
# 3    AZ                                  20.63
# 4    CA                                  16.21
# 5    CO                                  16.39
# 6    CT                                  16.67
# 7    DC                                  20.74
# 8    DE                                  21.23
# 9    FL                                  22.03
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              31.94
# 1                                              45.75
# 2                                              45.94
# 3                                              32.79
# 4                                              19.71
# 5                                              28.78
# 6                                              33.35
# ...

# %% [markdown]
# # Combine data from all worksheets

# %%
# Combine data from all worksheets.
df_Covid_CH_state = pd.concat(df_dict.values(), ignore_index=True)

# Display first 10 rows.
df_Covid_CH_state.head(10)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  25.02
# 1    AL                                  33.45
# 2    AR                                  32.93
# 3    AZ                                  26.45
# 4    CA                                  20.73
# 5    CO                                  20.41
# 6    CT                                  21.39
# 7    DC                                  26.10
# 8    DE                                  26.05
# 9    FL                                  26.81
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.15
# 1                                              51.47
# 2                                              52.27
# 3                                              41.21
# 4                                              24.98
# 5                                              34.63
# 6                                              40.67
# ...

# %% [markdown]
# # ETL Method

# %%
# Print total rows of new DataFrame. 
print(f" There are {len(df_Covid_CH_state)} total rows in the dataframe.")

# Show NaN values.
df_Covid_CH_state.isna().sum()
# Out:
#  There are 408 total rows in the dataframe.
# state                                                                    0
# Share with Subprime Credit Score, All                                    0
# Share with Subprime Credit Score, Communities of Color                  39
# Share with Subprime Credit Score, Majority White Communities             0
# Share with Any Debt in Collections, All                                  0
# Share with Any Debt in Collections, Communities of Color                39
# Share with Any Debt in Collections, Majority White Communities           0
# Median Debt in Collections, All                                          0
# Median Debt in Collections, Communities of Color                        54
# Median Debt in Collections, Majority White Communities                   8
# Average Credit Card Utilization, All                                     0
# Average Credit Card Utilization, Communities of Color                   55
# ...

# %%
# Display dtypes.
df_Covid_CH_state.dtypes
# Out:
# state                                                                   object
# Share with Subprime Credit Score, All                                  float64
# Share with Subprime Credit Score, Communities of Color                 float64
# Share with Subprime Credit Score, Majority White Communities           float64
# Share with Any Debt in Collections, All                                float64
# Share with Any Debt in Collections, Communities of Color               float64
# Share with Any Debt in Collections, Majority White Communities         float64
# Median Debt in Collections, All                                         object
# Median Debt in Collections, Communities of Color                        object
# Median Debt in Collections, Majority White Communities                  object
# Average Credit Card Utilization, All                                   float64
# Average Credit Card Utilization, Communities of Color                  float64
# ...

# %%
# Explore data.
df_Covid_CH_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 40 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   state                                                                408 non-null    object
#  1   Share with Subprime Credit Score, All                                408 non-null    float64
#  2   Share with Subprime Credit Score, Communities of Color               369 non-null    float64
#  3   Share with Subprime Credit Score, Majority White Communities         408 non-null    float64
#  4   Share with Any Debt in Collections, All                              408 non-null    float64
#  5   Share with Any Debt in Collections, Communities of Color             369 non-null    float64
# ...

# %% [markdown]
# Convert columns with 'object' data types as an integers or 'int'.

# %%
# Verify selected column for preview analysis is an object.
df_Covid_CH_state['Median Debt in Collections, All'].dtype
# Out:
# dtype('O')

# %%
# Use DataFrame.columns() to previw columns with 'object'.

# 'state' column.
for column in df_Covid_CH_state.columns[:1]:
     print(df_Covid_CH_state[column].head())

# 'median debt in collections...' column.
for column in df_Covid_CH_state.columns[7:10]:
    print(df_Covid_CH_state[column].head())

# 'median medical debt in collection...' column.
for column in df_Covid_CH_state.columns[34:37]:
    print(df_Covid_CH_state[column].head())
# Out:
# 0    AK
# 1    AL
# 2    AR
# 3    AZ
# 4    CA
# Name: state, dtype: object
# 0    $2073
# 1    $1917
# 2    $1671
# 3    $2051
# 4    $1842
# Name: Median Debt in Collections, All, dtype: object
# 0    $1248
# 1    $1916
# 2    $1847
# 3    $1995
# 4    $1848
# Name: Median Debt in Collections, Communities of Color, dtype: object
# 0    $2205
# 1    $1916
# 2    $1650
# 3    $2037
# 4    $1679
# Name: Median Debt in Collections, Majority White Communities, dtype: object
# 0    $1255
# 1     $973
# 2     $647
# 3     $938
# 4     $770
# Name: Median Medical Debt in Collections, All, dtype: object
# 0     $752
# 1    $1055
# 2     $611
# 3    $1008
# 4     $793
# Name: Median Medical Debt in Collections, Communities of Color, dtype: object
# 0    $1248
# 1     $931
# 2     $655
# 3     $892
# 4     $716
# Name: Median Medical Debt in Collections, Majority White Communities, dtype: object

# %%
# Replace NaN values with 0.
df_Covid_CH_state =  df_Covid_CH_state.fillna(0)

# Preview data. 
df_Covid_CH_state.head(5)
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  25.02
# 1    AL                                  33.45
# 2    AR                                  32.93
# 3    AZ                                  26.45
# 4    CA                                  20.73
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.15
# 1                                              51.47
# 2                                              52.27
# 3                                              41.21
# 4                                              24.98
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              19.97
# 1                                              28.70
# 2                                              30.24
# 3                                              18.94
# 4                                              14.10
#
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_state['Median Debt in Collections, All'] = df_Covid_CH_state['Median Debt in Collections, All'].apply(lambda x: x.replace('$', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_state.head()
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  25.02
# 1    AL                                  33.45
# 2    AR                                  32.93
# 3    AZ                                  26.45
# 4    CA                                  20.73
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.15
# 1                                              51.47
# 2                                              52.27
# 3                                              41.21
# 4                                              24.98
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              19.97
# 1                                              28.70
# 2                                              30.24
# 3                                              18.94
# 4                                              14.10
#
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_state['Median Debt in Collections, Communities of Color'] = df_Covid_CH_state['Median Debt in Collections, Communities of Color'].apply(lambda x: x.replace('$', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_state.head()
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  25.02
# 1    AL                                  33.45
# 2    AR                                  32.93
# 3    AZ                                  26.45
# 4    CA                                  20.73
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.15
# 1                                              51.47
# 2                                              52.27
# 3                                              41.21
# 4                                              24.98
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              19.97
# 1                                              28.70
# 2                                              30.24
# 3                                              18.94
# 4                                              14.10
#
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_state['Median Debt in Collections, Majority White Communities'] = df_Covid_CH_state['Median Debt in Collections, Majority White Communities'].apply(lambda x: x.replace('$', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_state.head()
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  25.02
# 1    AL                                  33.45
# 2    AR                                  32.93
# 3    AZ                                  26.45
# 4    CA                                  20.73
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.15
# 1                                              51.47
# 2                                              52.27
# 3                                              41.21
# 4                                              24.98
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              19.97
# 1                                              28.70
# 2                                              30.24
# 3                                              18.94
# 4                                              14.10
#
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_state['Median Medical Debt in Collections, All'] = df_Covid_CH_state['Median Medical Debt in Collections, All'].apply(lambda x: x.replace('$', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_state.head()
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  25.02
# 1    AL                                  33.45
# 2    AR                                  32.93
# 3    AZ                                  26.45
# 4    CA                                  20.73
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.15
# 1                                              51.47
# 2                                              52.27
# 3                                              41.21
# 4                                              24.98
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              19.97
# 1                                              28.70
# 2                                              30.24
# 3                                              18.94
# 4                                              14.10
#
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_state['Median Medical Debt in Collections, Communities of Color'] = df_Covid_CH_state['Median Medical Debt in Collections, Communities of Color'].apply(lambda x: x.replace('$', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data.
df_Covid_CH_state.head()
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  25.02
# 1    AL                                  33.45
# 2    AR                                  32.93
# 3    AZ                                  26.45
# 4    CA                                  20.73
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.15
# 1                                              51.47
# 2                                              52.27
# 3                                              41.21
# 4                                              24.98
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              19.97
# 1                                              28.70
# 2                                              30.24
# 3                                              18.94
# 4                                              14.10
#
# ...

# %%
# Convert string to integer/float.

# Convert selected column to int and remove '$' symbol. 
df_Covid_CH_state['Median Medical Debt in Collections, Majority White Communities'] = df_Covid_CH_state['Median Medical Debt in Collections, Majority White Communities'].apply(lambda x: x.replace('$', '')
                                if isinstance(x, str) else x).astype(int)

# Preview data. 
df_Covid_CH_state.head()
# Out:
#   state  Share with Subprime Credit Score, All  \
# 0    AK                                  25.02
# 1    AL                                  33.45
# 2    AR                                  32.93
# 3    AZ                                  26.45
# 4    CA                                  20.73
#
#    Share with Subprime Credit Score, Communities of Color  \
# 0                                              35.15
# 1                                              51.47
# 2                                              52.27
# 3                                              41.21
# 4                                              24.98
#
#    Share with Subprime Credit Score, Majority White Communities  \
# 0                                              19.97
# 1                                              28.70
# 2                                              30.24
# 3                                              18.94
# 4                                              14.10
#
# ...

# %%
# Dimensions of new dataset.
df_Covid_CH_state.shape
# Out:
# (408, 40)

# %%
# Summary for each variable. 
df_Covid_CH_state.describe()
# Out:
#        Share with Subprime Credit Score, All  \
# count                             408.000000
# mean                               22.024167
# std                                 5.732731
# min                                10.760000
# 25%                                17.207500
# 50%                                21.505000
# 75%                                26.452500
# max                                36.000000
#
#        Share with Subprime Credit Score, Communities of Color  \
# count                                         408.000000
# mean                                           35.420931
# std                                            15.037296
# min                                             0.000000
# 25%                                            30.545000
# 50%                                            36.980000
# 75%                                            45.832500
# max                                            73.080000
#
# ...

# %%
# Verify that all dtypes in new Dataframe are int/float with the exception of 'state' column for potential mapping purposes.
df_Covid_CH_state.dtypes
# Out:
# state                                                                   object
# Share with Subprime Credit Score, All                                  float64
# Share with Subprime Credit Score, Communities of Color                 float64
# Share with Subprime Credit Score, Majority White Communities           float64
# Share with Any Debt in Collections, All                                float64
# Share with Any Debt in Collections, Communities of Color               float64
# Share with Any Debt in Collections, Majority White Communities         float64
# Median Debt in Collections, All                                          int64
# Median Debt in Collections, Communities of Color                         int64
# Median Debt in Collections, Majority White Communities                   int64
# Average Credit Card Utilization, All                                   float64
# Average Credit Card Utilization, Communities of Color                  float64
# ...

# %%
#Exporting cleaned data into new csv file.
df_Covid_CH_state.to_csv('Cleaned_UI_Covid_CH_bystate.csv')
