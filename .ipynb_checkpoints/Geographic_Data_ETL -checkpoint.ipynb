# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
# Load the data
file_path = Path('Resources/CAEMP25N_BEA.csv')
df = pd.read_csv(file_path)

# %%
#preview data

df.head()
# Out:
#   GeoFips                               GeoName  LineCode  \
# 0     998  United States (Metropolitan Portion)       NaN
# 1     998  United States (Metropolitan Portion)      10.0
# 2     998  United States (Metropolitan Portion)       NaN
# 3     998  United States (Metropolitan Portion)      20.0
# 4     998  United States (Metropolitan Portion)      40.0
#
#                          Description       2016       2017       2018  \
# 0        Employment by place of work        NaN        NaN        NaN
# 1  Total employment (number of jobs)  169970416  172906517  176616181
# 2                            By type        NaN        NaN        NaN
# 3         Wage and salary employment  132630405  134570663  136851441
# 4             Proprietors employment   37340011   38335854   39764740
#
#         2019       2020
# 0        NaN        NaN
# 1  178045966  168252028
# 2        NaN        NaN
# 3  138926673  130532723
# 4   39119293   37719305

# %%
#check data types
df.dtypes
# Out:
# GeoFips         object
# GeoName         object
# LineCode       float64
# Description     object
# 2016            object
# 2017            object
# 2018            object
# 2019            object
# 2020            object
# dtype: object

# %%
#discover all columns in dataframe
df.columns.to_list()
# Out:
# ['GeoFips',
#  'GeoName',
#  'LineCode',
#  'Description',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %%
#count number of rows 
len(df. index)
# Out:
# 4329

# %%
#count number of null values in raw dataset
df.isna().sum().sum()
# Out:
# 2233

# %%
#drop null values 
new_df = df.dropna()

# %%
#checking number of rows after dropping null values
len(new_df.index)
# Out:
# 3960

# %%
#delete GeoFips

del new_df['GeoFips']

# %%
#drop lineode
del new_df['LineCode']

# %%
new_df.head()
# Out:
#                                 GeoName  \
# 1  United States (Metropolitan Portion)
# 3  United States (Metropolitan Portion)
# 4  United States (Metropolitan Portion)
# 5  United States (Metropolitan Portion)
# 6  United States (Metropolitan Portion)
#
#                              Description       2016       2017       2018  \
# 1      Total employment (number of jobs)  169970416  172906517  176616181
# 3             Wage and salary employment  132630405  134570663  136851441
# 4                 Proprietors employment   37340011   38335854   39764740
# 5            Farm proprietors employment     792909     784231     779376
# 6      Nonfarm proprietors employment 2/   36547102   37551623   38985364
#
#         2019       2020
# 1  178045966  168252028
# 3  138926673  130532723
# 4   39119293   37719305
# 5     777526     775462
# 6   38341767   36943843

# %%
#drop rows where year column has data with 'D' in it. making copy not to mess with new DF

df2= new_df

df2.drop(df2[df2['2016'] == '(D)'].index,inplace = True)
df2.drop(df2[df2['2017'] == '(D)'].index,inplace = True)
df2.drop(df2[df2['2018'] == '(D)'].index,inplace = True)
df2.drop(df2[df2['2019'] == '(D)'].index,inplace = True)
df2.drop(df2[df2['2020'] == '(D)'].index,inplace = True)
# Out:
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
len(df2.index)
# Out:
# 3460

# %%
df2.head()
# Out:
#                                 GeoName  \
# 1  United States (Metropolitan Portion)
# 3  United States (Metropolitan Portion)
# 4  United States (Metropolitan Portion)
# 5  United States (Metropolitan Portion)
# 6  United States (Metropolitan Portion)
#
#                              Description       2016       2017       2018  \
# 1      Total employment (number of jobs)  169970416  172906517  176616181
# 3             Wage and salary employment  132630405  134570663  136851441
# 4                 Proprietors employment   37340011   38335854   39764740
# 5            Farm proprietors employment     792909     784231     779376
# 6      Nonfarm proprietors employment 2/   36547102   37551623   38985364
#
#         2019       2020
# 1  178045966  168252028
# 3  138926673  130532723
# 4   39119293   37719305
# 5     777526     775462
# 6   38341767   36943843

# %%
df2.tail()
# Out:
#                                    GeoName  \
# 4314  Far West (Nonmetropolitan Portion) *
# 4315  Far West (Nonmetropolitan Portion) *
# 4316  Far West (Nonmetropolitan Portion) *
# 4317  Far West (Nonmetropolitan Portion) *
# 4319  Far West (Nonmetropolitan Portion) *
#
#                                     Description       2016       2017  \
# 4314      Government and government enterprises     292064     295132
# 4315                           Federal civilian      26206      25946
# 4316                                   Military      22225      23324
# 4317                            State and local     243633     245862
# 4319                           Local government  180,134 E  181,891 E
#
#            2018       2019       2020
# 4314     295547     300541     287943
# 4315      25362      25451      26608
# 4316      21271      21907      21728
# 4317     248914     253183     239607
# 4319  184,070 E  184,103 E  170,533 E

# %%
df2.dtypes
# Out:
# GeoName        object
# Description    object
# 2016           object
# 2017           object
# 2018           object
# 2019           object
# 2020           object
# dtype: object

# %%
#removing all "E"s from columns and replacing them in data frome 
df2['2016'] = df2['2016'].str.replace('E','')
df2['2017'] = df2['2017'].str.replace('E','')
df2['2018'] = df2['2018'].str.replace('E','')
df2['2019'] = df2['2019'].str.replace('E','')
df2['2020'] = df2['2020'].str.replace('E','')
# Out:
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.tail()
# Out:
#                                    GeoName  \
# 4314  Far West (Nonmetropolitan Portion) *
# 4315  Far West (Nonmetropolitan Portion) *
# 4316  Far West (Nonmetropolitan Portion) *
# 4317  Far West (Nonmetropolitan Portion) *
# 4319  Far West (Nonmetropolitan Portion) *
#
#                                     Description      2016      2017      2018  \
# 4314      Government and government enterprises    292064    295132    295547
# 4315                           Federal civilian     26206     25946     25362
# 4316                                   Military     22225     23324     21271
# 4317                            State and local    243633    245862    248914
# 4319                           Local government  180,134   181,891   184,070
#
#           2019      2020
# 4314    300541    287943
# 4315     25451     26608
# 4316     21907     21728
# 4317    253183    239607
# 4319  184,103   170,533

# %%
df2.dtypes
# Out:
# GeoName        object
# Description    object
# 2016           object
# 2017           object
# 2018           object
# 2019           object
# 2020           object
# dtype: object

# %%
#dropping all rows with all 0 values

df2.drop(df2[df2['2016'] == '0'].index,inplace = True)
df2.drop(df2[df2['2017'] == '0'].index,inplace = True)
df2.drop(df2[df2['2018'] == '0'].index,inplace = True)
df2.drop(df2[df2['2019'] == '0'].index,inplace = True)
df2.drop(df2[df2['2020'] == '0'].index,inplace = True)
# Out:
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
len(df2.index)
# Out:
# 3325

# %%
#removing commas from all rows 

df2['2016'] = df2['2016'].str.replace(',','')
df2['2017'] = df2['2017'].str.replace(',','')
df2['2018'] = df2['2018'].str.replace(',','')
df2['2019'] = df2['2019'].str.replace(',','')
df2['2020'] = df2['2020'].str.replace(',','')
# Out:
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df2.head()
# Out:
#                                 GeoName  \
# 1  United States (Metropolitan Portion)
# 3  United States (Metropolitan Portion)
# 4  United States (Metropolitan Portion)
# 5  United States (Metropolitan Portion)
# 6  United States (Metropolitan Portion)
#
#                              Description       2016       2017       2018  \
# 1      Total employment (number of jobs)  169970416  172906517  176616181
# 3             Wage and salary employment  132630405  134570663  136851441
# 4                 Proprietors employment   37340011   38335854   39764740
# 5            Farm proprietors employment     792909     784231     779376
# 6      Nonfarm proprietors employment 2/   36547102   37551623   38985364
#
#         2019       2020
# 1  178045966  168252028
# 3  138926673  130532723
# 4   39119293   37719305
# 5     777526     775462
# 6   38341767   36943843

# %%
df2.tail()
# Out:
#                                    GeoName  \
# 4314  Far West (Nonmetropolitan Portion) *
# 4315  Far West (Nonmetropolitan Portion) *
# 4316  Far West (Nonmetropolitan Portion) *
# 4317  Far West (Nonmetropolitan Portion) *
# 4319  Far West (Nonmetropolitan Portion) *
#
#                                     Description     2016     2017     2018  \
# 4314      Government and government enterprises   292064   295132   295547
# 4315                           Federal civilian    26206    25946    25362
# 4316                                   Military    22225    23324    21271
# 4317                            State and local   243633   245862   248914
# 4319                           Local government  180134   181891   184070
#
#          2019     2020
# 4314   300541   287943
# 4315    25451    26608
# 4316    21907    21728
# 4317   253183   239607
# 4319  184103   170533

# %%
# converting multiple columns to INT for later use 

df2[['2016','2017','2018','2019','2020']] =df2[['2016','2017','2018','2019','2020']].astype(str).astype(int)
# Out:
# C:\Users\palum\anaconda3\envs\GreatRes\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
#verifying data types

df2.dtypes
# Out:
# GeoName        object
# Description    object
# 2016            int32
# 2017            int32
# 2018            int32
# 2019            int32
# 2020            int32
# dtype: object

# %%
df2.head()
# Out:
#                                 GeoName  \
# 1  United States (Metropolitan Portion)
# 3  United States (Metropolitan Portion)
# 4  United States (Metropolitan Portion)
# 5  United States (Metropolitan Portion)
# 6  United States (Metropolitan Portion)
#
#                              Description       2016       2017       2018  \
# 1      Total employment (number of jobs)  169970416  172906517  176616181
# 3             Wage and salary employment  132630405  134570663  136851441
# 4                 Proprietors employment   37340011   38335854   39764740
# 5            Farm proprietors employment     792909     784231     779376
# 6      Nonfarm proprietors employment 2/   36547102   37551623   38985364
#
#         2019       2020
# 1  178045966  168252028
# 3  138926673  130532723
# 4   39119293   37719305
# 5     777526     775462
# 6   38341767   36943843

# %%
len(df2)
# Out:
# 3325

# %%
#exporting cleaned data into new csv file

df2.to_csv('cleaned_geographic_data.csv')

# %%
df3 = df2

# %%
df3
# Out:
#                                    GeoName  \
# 1     United States (Metropolitan Portion)
# 3     United States (Metropolitan Portion)
# 4     United States (Metropolitan Portion)
# 5     United States (Metropolitan Portion)
# 6     United States (Metropolitan Portion)
# ...                                    ...
# 4314  Far West (Nonmetropolitan Portion) *
# 4315  Far West (Nonmetropolitan Portion) *
# 4316  Far West (Nonmetropolitan Portion) *
# 4317  Far West (Nonmetropolitan Portion) *
# 4319  Far West (Nonmetropolitan Portion) *
#
#                                     Description       2016       2017  \
# 1             Total employment (number of jobs)  169970416  172906517
# 3                    Wage and salary employment  132630405  134570663
# 4                        Proprietors employment   37340011   38335854
# 5                   Farm proprietors employment     792909     784231
# 6             Nonfarm proprietors employment 2/   36547102   37551623
# ...                                         ...        ...        ...
# 4314      Government and government enterprises     292064     295132
# 4315                           Federal civilian      26206      25946
# 4316                                   Military      22225      23324
# 4317                            State and local     243633     245862
# 4319                           Local government     180134     181891
#
#            2018       2019       2020
# 1     176616181  178045966  168252028
# 3     136851441  138926673  130532723
# 4      39764740   39119293   37719305
# 5        779376     777526     775462
# 6      38985364   38341767   36943843
# ...         ...        ...        ...
# 4314     295547     300541     287943
# 4315      25362      25451      26608
# 4316      21271      21907      21728
# 4317     248914     253183     239607
# 4319     184070     184103     170533
#
# [3325 rows x 7 columns]

# %%
new_keys = [
"Total employment (number of jobs)",
"  Wage and salary employment",
"  Proprietors employment",
"    Farm proprietors employment",
"    Nonfarm proprietors employment 2/",
"  Farm employment",
"  Nonfarm employment",
"    Private nonfarm employment",
"      Forestry, fishing, and related activities",
"      Mining, quarrying, and oil and gas extraction",
"      Utilities",
"      Construction",
"      Manufacturing",
"      Wholesale trade",
"      Retail trade",
"      Transportation and warehousing",
"      Information",
"      Finance and insurance",
"      Real estate and rental and leasing",
"      Professional, scientific, and technical services",
"      Management of companies and enterprises",
"      Administrative and support and waste management and remediation services",
"      Educational services",
"      Health care and social assistance",
"      Arts, entertainment, and recreation",
"      Accommodation and food services",
"      Other services (except government and government enterprises)",
"    Government and government enterprises",
"      Federal civilian",
"      Military",
"      State and local",
"        State government",
"        Local government",
]
new_names = [
"- Total employment (number of jobs)",
"Wage and salary employment",
"- Proprietors employment",
"Proprietors employment Farm proprietors employment",
"Proprietors employmentNonfarm proprietors employment 2/",
"Farm employment",
"- Nonfarm employment",
"- Nonfarm employment Private nonfarm employment",
"Nonfarm employment Private nonfarm employment Forestry, fishing, and related activities",
"Nonfarm employment Private nonfarm employment Mining, quarrying, and oil and gas extraction",
"Nonfarm employment Private nonfarm employment Utilities",
"Nonfarm employment Private nonfarm employment Construction",
"Nonfarm employment Private nonfarm employment Manufacturing",
"Nonfarm employment Private nonfarm employment Wholesale trade",
"Nonfarm employment Private nonfarm employment Retail trade",
"Nonfarm employment Private nonfarm employment Transportation and warehousing",
"Nonfarm employment Private nonfarm employment Information",
"Nonfarm employment Private nonfarm employment Finance and insurance",
"Nonfarm employment Private nonfarm employment Real estate and rental and leasing",
"Nonfarm employment Private nonfarm employment Professional, scientific, and technical services",
"Nonfarm employment Private nonfarm employment Management of companies and enterprises",
"Nonfarm employment Private nonfarm employment Administrative and support and waste management and remediation services",
"Nonfarm employment Private nonfarm employment Educational services",
"Nonfarm employment Private nonfarm employment Health care and social assistance",
"Nonfarm employment Private nonfarm employment Arts, entertainment, and recreation",
"Nonfarm employment Private nonfarm employment Accommodation and food services",
"Nonfarm employment Private nonfarm employment Other services (except government and government enterprises)",
"- Government and government enterprises",
"Government and government enterprises Federal civilian",
"Government and government enterprises Military",
"- Government and government enterprises State and local",
"Government and government enterprises State and local State government",
"Government and government enterprises State and local Local government",
]

# %%
new_names2 = []
for i in range(len(new_names)):
    if new_names[i][0:2] != '- ':
        new_names2.append(new_names[i])
    else:
        new_names2.append('0')
        
new_names2
# Out:
# ['0',
#  'Wage and salary employment',
#  '0',
#  'Proprietors employment Farm proprietors employment',
#  'Proprietors employmentNonfarm proprietors employment 2/',
#  'Farm employment',
#  '0',
#  '0',
#  'Nonfarm employment Private nonfarm employment Forestry, fishing, and related activities',
#  'Nonfarm employment Private nonfarm employment Mining, quarrying, and oil and gas extraction',
#  'Nonfarm employment Private nonfarm employment Utilities',
#  'Nonfarm employment Private nonfarm employment Construction',
#  'Nonfarm employment Private nonfarm employment Manufacturing',
#  'Nonfarm employment Private nonfarm employment Wholesale trade',
#  'Nonfarm employment Private nonfarm employment Retail trade',
#  'Nonfarm employment Private nonfarm employment Transportation and warehousing',
#  'Nonfarm employment Private nonfarm employment Information',
#  'Nonfarm employment Private nonfarm employment Finance and insurance',
#  'Nonfarm employment Private nonfarm employment Real estate and rental and leasing',
#  'Nonfarm employment Private nonfarm employment Professional, scientific, and technical services',
#  'Nonfarm employment Private nonfarm employment Management of companies and enterprises',
#  'Nonfarm employment Private nonfarm employment Administrative and support and waste management and remediation services',
#  'Nonfarm employment Private nonfarm employment Educational services',
#  'Nonfarm employment Private nonfarm employment Health care and social assistance',
#  'Nonfarm employment Private nonfarm employment Arts, entertainment, and recreation',
#  'Nonfarm employment Private nonfarm employment Accommodation and food services',
#  'Nonfarm employment Private nonfarm employment Other services (except government and government enterprises)',
#  '0',
#  'Government and government enterprises Federal civilian',
#  'Government and government enterprises Military',
#  '0',
#  'Government and government enterprises State and local State government',
#  'Government and government enterprises State and local Local government']

# %%
repl = {x:y for [x, y ] in zip(new_keys, new_names2)}

# %%
df3 = df3.replace(repl)

# %%
df4 = df3[df3['Description'] != '0']
df4
# Out:
#                                    GeoName  \
# 3     United States (Metropolitan Portion)
# 5     United States (Metropolitan Portion)
# 6     United States (Metropolitan Portion)
# 8     United States (Metropolitan Portion)
# 11    United States (Metropolitan Portion)
# ...                                    ...
# 4303  Far West (Nonmetropolitan Portion) *
# 4313  Far West (Nonmetropolitan Portion) *
# 4315  Far West (Nonmetropolitan Portion) *
# 4316  Far West (Nonmetropolitan Portion) *
# 4319  Far West (Nonmetropolitan Portion) *
#
#                                             Description       2016       2017  \
# 3                            Wage and salary employment  132630405  134570663
# 5     Proprietors employment Farm proprietors employ...     792909     784231
# 6     Proprietors employmentNonfarm proprietors empl...   36547102   37551623
# 8                                       Farm employment    1303796    1291110
# 11    Nonfarm employment Private nonfarm employment ...     600487     603123
# ...                                                 ...        ...        ...
# 4303  Nonfarm employment Private nonfarm employment ...      13469      12712
# 4313  Nonfarm employment Private nonfarm employment ...      87123      86248
# 4315  Government and government enterprises Federal ...      26206      25946
# 4316     Government and government enterprises Military      22225      23324
# 4319  Government and government enterprises State an...     180134     181891
#
#            2018       2019       2020
# 3     136851441  138926673  130532723
# 5        779376     777526     775462
# 6      38985364   38341767   36943843
# 8       1284916    1281642    1268814
# 11       618202     612598     594610
# ...         ...        ...        ...
# 4303      12631      11943      12356
# 4313      89268      85980      81755
# 4315      25362      25451      26608
# 4316      21271      21907      21728
# 4319     184070     184103     170533
#
# [2629 rows x 7 columns]

# %%
df4.to_csv('cleaned_geographic_data.csv')
