# %% [markdown]
# ## Collect and further clean the dataset for Machine Learning purposes.

# %%
# Import Pandas Dependencies.
import pandas as pd
import numpy as np
from pathlib import Path

# Import Matplotlib Dependencies.
import matplotlib.pyplot as plt

# Import Sklearn Dependencies.
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
# Load the CSV file as a Pandas DataFrame and preview the DataFrame.
df = pd.read_csv(Path('Working Resources/Cleaned_geographic_Data.csv'))
df.head()
# Out:
#                           GeoName  \
# 0  Alabama (Metropolitan Portion)
# 1  Alabama (Metropolitan Portion)
# 2  Alabama (Metropolitan Portion)
# 3  Alabama (Metropolitan Portion)
# 4  Alabama (Metropolitan Portion)
#
#                                          Description     2016     2017  \
# 0                         Wage and salary employment  1643706  1664641
# 1  Proprietors employment Farm proprietors employ...    17653    17142
# 2  Proprietors employmentNonfarm proprietors empl...   423880   432197
# 3                                    Farm employment    21352    21534
# 4  Nonfarm employment Private nonfarm employment ...     8693     7939
#
#       2018     2019     2020
# 0  1686588  1711156  1643053
# 1    16771    16389    16466
# 2   447698   442971   428638
# 3    20490    19416    19872
# 4     7353     7000     6494

# %%
# Determine value counts on GeoName column.
df['GeoName'].value_counts()
# Out:
# Iowa (Metropolitan Portion)                 27
# Kansas (Metropolitan Portion)               27
# Michigan (Metropolitan Portion)             27
# Texas (Metropolitan Portion)                27
# New Jersey (Metropolitan Portion)           27
#                                             ..
# Oklahoma (Nonmetropolitan Portion) *        15
# South Dakota (Nonmetropolitan Portion) *    14
# Idaho (Nonmetropolitan Portion) *           14
# Maryland (Nonmetropolitan Portion) *        11
# North Dakota (Nonmetropolitan Portion) *    10
# Name: GeoName, Length: 98, dtype: int64

# %%
# Split GeoName. 
df[['State', 'GeoName']] = df['GeoName'].str.split('(', expand=True)
df.head()
# Out:
#                  GeoName                                        Description  \
# 0  Metropolitan Portion)                         Wage and salary employment
# 1  Metropolitan Portion)  Proprietors employment Farm proprietors employ...
# 2  Metropolitan Portion)  Proprietors employmentNonfarm proprietors empl...
# 3  Metropolitan Portion)                                    Farm employment
# 4  Metropolitan Portion)  Nonfarm employment Private nonfarm employment ...
#
#       2016     2017     2018     2019     2020     State
# 0  1643706  1664641  1686588  1711156  1643053  Alabama
# 1    17653    17142    16771    16389    16466  Alabama
# 2   423880   432197   447698   442971   428638  Alabama
# 3    21352    21534    20490    19416    19872  Alabama
# 4     8693     7939     7353     7000     6494  Alabama

# %%
# Reorder of columns in DataFrame. 
df = df[['State', 'GeoName', 'Description', '2016', '2017', '2018', '2019', '2020']]
df
# Out:
#          State                     GeoName  \
# 0     Alabama        Metropolitan Portion)
# 1     Alabama        Metropolitan Portion)
# 2     Alabama        Metropolitan Portion)
# 3     Alabama        Metropolitan Portion)
# 4     Alabama        Metropolitan Portion)
# ...        ...                         ...
# 2254  Wyoming   Nonmetropolitan Portion) *
# 2255  Wyoming   Nonmetropolitan Portion) *
# 2256  Wyoming   Nonmetropolitan Portion) *
# 2257  Wyoming   Nonmetropolitan Portion) *
# 2258  Wyoming   Nonmetropolitan Portion) *
#
#                                             Description     2016     2017  \
# 0                            Wage and salary employment  1643706  1664641
# 1     Proprietors employment Farm proprietors employ...    17653    17142
# 2     Proprietors employmentNonfarm proprietors empl...   423880   432197
# 3                                       Farm employment    21352    21534
# 4     Nonfarm employment Private nonfarm employment ...     8693     7939
# ...                                                 ...      ...      ...
# 2254  Nonfarm employment Private nonfarm employment ...    12381    12314
# 2255  Government and government enterprises Federal ...     4166     4120
# 2256     Government and government enterprises Military     2118     2124
# 2257  Government and government enterprises State an...    10827    10529
# 2258  Government and government enterprises State an...    35106    34445
#
#          2018     2019     2020
# 0     1686588  1711156  1643053
# 1       16771    16389    16466
# 2      447698   442971   428638
# 3       20490    19416    19872
# 4        7353     7000     6494
# ...       ...      ...      ...
# 2254    12727    12546    11896
# 2255     4101     4155     4285
# 2256     2092     2106     2075
# 2257    10454    10090     9722
# 2258    33902    34692    33390
#
# [2259 rows x 8 columns]

# %%
# Value counts of GeoName column.
df['GeoName'].value_counts()
# Out:
# Metropolitan Portion)         1275
# Nonmetropolitan Portion) *     984
# Name: GeoName, dtype: int64

# %%
# Replace values with '0'(Metropolitan Portion) and '1'(Nonmetropolitan Portion).
df['GeoName'].replace(['Metropolitan Portion)', 'Nonmetropolitan Portion) *'], [0, 1], inplace= True)

# Display.
df
# Out:
#          State  GeoName                                        Description  \
# 0     Alabama         0                         Wage and salary employment
# 1     Alabama         0  Proprietors employment Farm proprietors employ...
# 2     Alabama         0  Proprietors employmentNonfarm proprietors empl...
# 3     Alabama         0                                    Farm employment
# 4     Alabama         0  Nonfarm employment Private nonfarm employment ...
# ...        ...      ...                                                ...
# 2254  Wyoming         1  Nonfarm employment Private nonfarm employment ...
# 2255  Wyoming         1  Government and government enterprises Federal ...
# 2256  Wyoming         1     Government and government enterprises Military
# 2257  Wyoming         1  Government and government enterprises State an...
# 2258  Wyoming         1  Government and government enterprises State an...
#
#          2016     2017     2018     2019     2020
# 0     1643706  1664641  1686588  1711156  1643053
# 1       17653    17142    16771    16389    16466
# 2      423880   432197   447698   442971   428638
# 3       21352    21534    20490    19416    19872
# 4        8693     7939     7353     7000     6494
# ...       ...      ...      ...      ...      ...
# 2254    12381    12314    12727    12546    11896
# 2255     4166     4120     4101     4155     4285
# 2256     2118     2124     2092     2106     2075
# 2257    10827    10529    10454    10090     9722
# 2258    35106    34445    33902    34692    33390
#
# [2259 rows x 8 columns]

# %% [markdown]
# ## Determining which variable to predict. Y (dependent) variable and X (independent) variables.

# %%
# Separate target values.
y = df['2020']
X = df.drop('2020', axis=1)

# %%
# Identify X parameter.
X = pd.get_dummies(data= X, columns=['State', 'Description'])

# Print the shape of X.
print(X.shape)

# Display preprocessed machine learning dataframe to model.
X.head()
# Out:
# (2259, 83)
#    GeoName     2016     2017     2018     2019  State_Alabama   State_Alaska   \
# 0        0  1643706  1664641  1686588  1711156               1              0
# 1        0    17653    17142    16771    16389               1              0
# 2        0   423880   432197   447698   442971               1              0
# 3        0    21352    21534    20490    19416               1              0
# 4        0     8693     7939     7353     7000               1              0
#
#    State_Arizona   State_Arkansas   State_California   ...  \
# 0               0                0                  0  ...
# 1               0                0                  0  ...
# 2               0                0                  0  ...
# 3               0                0                  0  ...
# 4               0                0                  0  ...
#
#    Description_Nonfarm employment Private nonfarm employment Other services (except government and government enterprises)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Description_Nonfarm employment Private nonfarm employment Professional, scientific, and technical services  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Description_Nonfarm employment Private nonfarm employment Real estate and rental and leasing  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Description_Nonfarm employment Private nonfarm employment Retail trade  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Description_Nonfarm employment Private nonfarm employment Transportation and warehousing  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Description_Nonfarm employment Private nonfarm employment Utilities  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Description_Nonfarm employment Private nonfarm employment Wholesale trade  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Description_Proprietors employment Farm proprietors employment  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Description_Proprietors employmentNonfarm proprietors employment 2/  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Description_Wage and salary employment
# 0                                       1
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
#
# [5 rows x 83 columns]

# %%
# Export converted ML file for reference.
X.to_csv('MachineLearning_GDP_By_State_geographic_data.csv')

# %%
# Split our data into training and testing.
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=66)

# %%
# Determine the shape of our training and testing sets.
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1694, 83)
# (565, 83)
# (1694,)
# (565,)

# %%
# Scale testing Data. 
X_train_scaled = StandardScaler().fit(X_train).transform(X_train)

# %%
X_train_scaled[:5]
# Out:
# array([[ 1.13134706, -0.27226636, -0.27328396, -0.271182  , -0.26900395,
#         -0.147353  , -0.13653208, -0.1409523 , -0.147353  , -0.13875846,
#         -0.14943062, -0.13875846, -0.10068341, -0.08794028, -0.13653208,
#         -0.1555114 , -0.1409523 , -0.13427154, -0.15350881, -0.14943062,
#         -0.14524822, -0.14524822, -0.14524822, -0.14311509, -0.147353  ,
#         -0.11203705, -0.14524822, -0.1409523 , -0.1555114 , -0.1409523 ,
#         -0.15749091, -0.12964074, -0.13875846, -0.15350881, -0.14524822,
#         -0.10650485, -0.13653208, -0.14943062, -0.147353  , -0.12726649,
#         -0.14943062, -0.14311509, -0.1409523 , -0.14943062, -0.10930431,
#         -0.1409523 , -0.12726649,  6.34957268, -0.15749091, -0.14524822,
#         -0.13427154, -0.1555114 , -0.16329932, -0.147353  , -0.14524822,
#         -0.13875846, -0.21821789, -0.20606198, -0.20606198, -0.19815096,
#         -0.18996217, -0.20134682, -0.19327328, -0.18996217, -0.1997543 ,
#         -0.19491074, -0.20292877, -0.13427154, -0.18828787, -0.1997543 ,
#         -0.18828787, -0.1997543 , -0.15350881, -0.1997543 , -0.18996217,
#          4.78112486, -0.2076137 , -0.18996217, -0.17795701, -0.19653653,
#         -0.21523218, -0.20606198, -0.21969826],
#        [-0.88390206, -0.17269039, -0.1722209 , -0.16100408, -0.15968039,
#         -0.147353  , -0.13653208, -0.1409523 , -0.147353  , -0.13875846,
#         -0.14943062, -0.13875846, -0.10068341, -0.08794028, -0.13653208,
#         -0.1555114 , -0.1409523 , -0.13427154, -0.15350881, -0.14943062,
#         -0.14524822, -0.14524822, -0.14524822, -0.14311509, -0.147353  ,
#         -0.11203705,  6.88476579, -0.1409523 , -0.1555114 , -0.1409523 ,
#         -0.15749091, -0.12964074, -0.13875846, -0.15350881, -0.14524822,
#         -0.10650485, -0.13653208, -0.14943062, -0.147353  , -0.12726649,
#         -0.14943062, -0.14311509, -0.1409523 , -0.14943062, -0.10930431,
#         -0.1409523 , -0.12726649, -0.15749091, -0.15749091, -0.14524822,
#         -0.13427154, -0.1555114 , -0.16329932, -0.147353  , -0.14524822,
#         -0.13875846, -0.21821789, -0.20606198, -0.20606198, -0.19815096,
#         -0.18996217, -0.20134682, -0.19327328, -0.18996217, -0.1997543 ,
#         -0.19491074, -0.20292877, -0.13427154, -0.18828787, -0.1997543 ,
#          5.31101653, -0.1997543 , -0.15350881, -0.1997543 , -0.18996217,
#         -0.2091558 , -0.2076137 , -0.18996217, -0.17795701, -0.19653653,
#         -0.21523218, -0.20606198, -0.21969826],
#        [ 1.13134706, -0.29779012, -0.29723551, -0.29694492, -0.29528784,
#         -0.147353  , -0.13653208, -0.1409523 , -0.147353  , -0.13875846,
#         -0.14943062,  7.20676765, -0.10068341, -0.08794028, -0.13653208,
#         -0.1555114 , -0.1409523 , -0.13427154, -0.15350881, -0.14943062,
#         -0.14524822, -0.14524822, -0.14524822, -0.14311509, -0.147353  ,
#         -0.11203705, -0.14524822, -0.1409523 , -0.1555114 , -0.1409523 ,
#         -0.15749091, -0.12964074, -0.13875846, -0.15350881, -0.14524822,
#         -0.10650485, -0.13653208, -0.14943062, -0.147353  , -0.12726649,
#         -0.14943062, -0.14311509, -0.1409523 , -0.14943062, -0.10930431,
#         -0.1409523 , -0.12726649, -0.15749091, -0.15749091, -0.14524822,
#         -0.13427154, -0.1555114 , -0.16329932, -0.147353  , -0.14524822,
#         -0.13875846, -0.21821789, -0.20606198, -0.20606198, -0.19815096,
#         -0.18996217,  4.96655481, -0.19327328, -0.18996217, -0.1997543 ,
#         -0.19491074, -0.20292877, -0.13427154, -0.18828787, -0.1997543 ,
#         -0.18828787, -0.1997543 , -0.15350881, -0.1997543 , -0.18996217,
#         -0.2091558 , -0.2076137 , -0.18996217, -0.17795701, -0.19653653,
#         -0.21523218, -0.20606198, -0.21969826],
#        [-0.88390206, -0.2378565 , -0.23514368, -0.23597472, -0.23656534,
#         -0.147353  , -0.13653208, -0.1409523 , -0.147353  , -0.13875846,
#         -0.14943062, -0.13875846, -0.10068341, -0.08794028, -0.13653208,
#         -0.1555114 , -0.1409523 , -0.13427154, -0.15350881, -0.14943062,
#         -0.14524822, -0.14524822, -0.14524822, -0.14311509, -0.147353  ,
#         -0.11203705, -0.14524822, -0.1409523 , -0.1555114 , -0.1409523 ,
#         -0.15749091, -0.12964074, -0.13875846, -0.15350881, -0.14524822,
#         -0.10650485, -0.13653208, -0.14943062, -0.147353  , -0.12726649,
#         -0.14943062, -0.14311509, -0.1409523 , -0.14943062,  9.14877041,
#         -0.1409523 , -0.12726649, -0.15749091, -0.15749091, -0.14524822,
#         -0.13427154, -0.1555114 , -0.16329932, -0.147353  , -0.14524822,
#         -0.13875846, -0.21821789, -0.20606198, -0.20606198, -0.19815096,
#         -0.18996217, -0.20134682, -0.19327328, -0.18996217, -0.1997543 ,
#         -0.19491074,  4.92783747, -0.13427154, -0.18828787, -0.1997543 ,
#         -0.18828787, -0.1997543 , -0.15350881, -0.1997543 , -0.18996217,
#         -0.2091558 , -0.2076137 , -0.18996217, -0.17795701, -0.19653653,
#         -0.21523218, -0.20606198, -0.21969826],
#        [-0.88390206,  2.45802185,  2.42279294,  2.37706361,  2.33292211,
#         -0.147353  , -0.13653208, -0.1409523 , -0.147353  ,  7.20676765,
#         -0.14943062, -0.13875846, -0.10068341, -0.08794028, -0.13653208,
#         -0.1555114 , -0.1409523 , -0.13427154, -0.15350881, -0.14943062,
#         -0.14524822, -0.14524822, -0.14524822, -0.14311509, -0.147353  ,
#         -0.11203705, -0.14524822, -0.1409523 , -0.1555114 , -0.1409523 ,
#         -0.15749091, -0.12964074, -0.13875846, -0.15350881, -0.14524822,
#         -0.10650485, -0.13653208, -0.14943062, -0.147353  , -0.12726649,
#         -0.14943062, -0.14311509, -0.1409523 , -0.14943062, -0.10930431,
#         -0.1409523 , -0.12726649, -0.15749091, -0.15749091, -0.14524822,
#         -0.13427154, -0.1555114 , -0.16329932, -0.147353  , -0.14524822,
#         -0.13875846, -0.21821789, -0.20606198, -0.20606198, -0.19815096,
#         -0.18996217, -0.20134682, -0.19327328, -0.18996217, -0.1997543 ,
#         -0.19491074, -0.20292877, -0.13427154, -0.18828787, -0.1997543 ,
#         -0.18828787,  5.00615006, -0.15350881, -0.1997543 , -0.18996217,
#         -0.2091558 , -0.2076137 , -0.18996217, -0.17795701, -0.19653653,
#         -0.21523218, -0.20606198, -0.21969826]])

# %%
# Verify the mean and standard deviation.
print(np.mean(X_train_scaled[:,0]))
print(np.std(X_train_scaled[:,0]))
# Out:
# 5.662530656883915e-17
# 0.9999999999999999
